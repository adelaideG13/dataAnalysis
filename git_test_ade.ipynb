# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git init dataAnalysis
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/dataAnalysis/.git/

# %%
# %cd dataAnalysis/
# Out:
# /content/drive/My Drive/dataAnalysis

# %%
# %ls -a
# Out:
# .git/

# %%
# !git status
# Out:
# On branch master
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git add .

# %%
# !git status
# Out:
# On branch master
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)
